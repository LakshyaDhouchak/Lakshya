# %%
from langchain_ollama import ChatOllama
from dotenv import load_dotenv
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
load_dotenv()
model =  ChatOllama(model = 'minimax-m3:cloud', temperature= 0.5)

prompt1 = PromptTemplate(
    template='Generate a detailed report on {topic}',
    input_variables=['topic']
)

prompt2 = PromptTemplate(
    template='Generate a 5 pointer summary from the following text \n {text}',
    input_variables=['text']
)

parser =  StrOutputParser()
chain = prompt1 | model | parser | prompt2 | model | parser
result = chain.invoke({'topic': 'Unemployment in India'})

print(result)
# Out:
# # 5-Point Summary: Unemployment in India
#
# ## 1. **Current State & Severity**
# India's unemployment rate stands at **6-8%** (2024-2025), with **youth unemployment reaching 12-20%**, affecting the world's largest young workforce. Significant disparities exist across gender (female participation only 25-30%), rural-urban divides, and states, while the economy needs to create **10-12 million jobs annually** to absorb new labor force entrants.
#
# ## 2. **Root Causes**
# The crisis stems from a **mismatch between rapid population growth (~12-15 million new workers yearly) and inadequate job creation**, compounded by skill gaps, outdated education curricula, capital-intensive growth models, rigid labor laws, technological disruption (AI/automation), and persistent gender and caste-based discrimination in workforce participation.
#
# ## 3. **Multiple Forms of Unemployment**
# India faces a complex blend of **structural, seasonal, disguised, frictional, cyclical, and educated unemployment**—with disguised unemployment rampant in agriculture (which employs 42-45% of workforce but contributes only 15-18% to GDP), and educated unemployment rising sharply among India's millions of graduates.
#
# ## 4. **Government Response**
# Major initiatives include **MGNREGA, PMKVY (skill development), PLI Scheme (14 sectors), Start-Up India, MUDRA Yojana, and Labor Code reforms**—all aimed at boosting employment, entrepreneurship, and manufacturing. However, implementation gaps, bureaucratic inefficiencies, and the dominance of the informal sector (80% of employment) limit their effectiveness.
#
# ## 5. **Path Forward & Projections**
# India must create **90-100 million non-agricultural jobs by 2030** through a multi-pronged strategy: reforming education, expanding skill training, boosting manufacturing to 25% of GDP, embracing the green economy, and preparing the workforce for AI-driven disruption. With the right policies, India's demographic dividend can drive inclusive growth; without action, the crisis will deepen with severe economic, social, and political consequences.
