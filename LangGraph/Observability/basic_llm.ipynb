# %%
from langchain_ollama import ChatOllama
from dotenv import load_dotenv
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate

# %%
load_dotenv()

model = ChatOllama(
    model="minimax-m3:cloud",
    temperature=0.5
)

prompt = PromptTemplate.from_template("{question}")
parser = StrOutputParser()

chain = prompt | model | parser

result = chain.invoke(
    {"question": "What is the capital of Peru?"}
)
print(result)
# Out:
# The capital of Peru is **Lima**. It is located on the country's Pacific coast and is the largest city in Peru, with a metropolitan population of over 10 million people. Lima was founded by Spanish conquistador Francisco Pizarro in 1535 and is known for its rich colonial history, vibrant culinary scene, and as a gateway to attractions like Machu Picchu.
