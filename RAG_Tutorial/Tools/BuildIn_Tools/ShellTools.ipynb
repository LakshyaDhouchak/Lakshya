# %%
from langchain_community.tools import ShellTool

shell_tool = ShellTool()
result = shell_tool.invoke('ollama list')
print(result)
# Out:
# Executing command:
#  ollama list
# NAME                       ID              SIZE      MODIFIED
# nomic-embed-text:latest    0a109f422b47    274 MB    10 days ago
# qwen3-embedding:8b         64b933495768    4.7 GB    11 days ago
# twwch/m3e-base:latest      4438b606c291    204 MB    11 days ago
# minimax-m3:cloud           d03a959f45c0    -         11 days ago
# qwen2.5:3b                 357c53fb659c    1.9 GB    11 days ago
