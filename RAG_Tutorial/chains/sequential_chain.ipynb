# %%
from langchain_ollama import ChatOllama
from dotenv import load_dotenv
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
load_dotenv()
model = ChatOllama(model = 'minimax-m3:cloud', temperature=0.5)
prompt1 = ChatPromptTemplate([
    ('human','write a detailed report on {topic}')
])
prompt2 = ChatPromptTemplate([
    ('human','write a 5 line summary of the following text.\n {text}')
])
parser = StrOutputParser()

# %%
chain = prompt1 | model | parser | prompt2 | model | parser
result = chain.invoke({'topic':'black hole'})
print(result)
# Out:
# Black holes are regions of spacetime where gravity is so intense that nothing, not even light, can escape beyond the event horizon, first theorized through Einstein's General Theory of Relativity. Key milestones include Karl Schwarzschild's 1916 mathematical solution, the 2015 LIGO detection of gravitational waves from merging black holes, and the Event Horizon Telescope's 2019 and 2022 images of M87* and Sagittarius A*. Black holes are classified by mass into stellar-mass, intermediate-mass, supermassive, and hypothetical primordial types, with supermassive ones residing at the centers of most large galaxies. Major unsolved questions include the information paradox, the true nature of singularities, and whether primordial black holes could explain dark matter. As both astrophysical objects and cultural symbols, black holes continue to challenge the boundaries of physics, with future observatories like LISA and JWST promising to deepen our understanding.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 4
#       1 chain = prompt1 | model | parser | prompt2 | model | parser
#       2 result = chain.invoke({'topic':'black hole'})
#       3 print(result)
# ----> 4 chain.get_graph().print_ascii()
#
# File d:\Lakshya\venv\Lib\site-packages\langchain_core\runnables\graph.py:523, in Graph.print_ascii(self)
#     521 def print_ascii(self) -> None:
#     522     """Print the graph as an ASCII art string."""
# --> 523     print(self.draw_ascii())
#
# File d:\Lakshya\venv\Lib\site-packages\langchain_core\runnables\graph.py:516, in Graph.draw_ascii(self)
#     513 # Import locally to prevent circular import
#     514 from langchain_core.runnables.graph_ascii import draw_ascii  # noqa: PLC0415
# --> 516 return draw_ascii(
#     517     {node.id: node.name for node in self.nodes.values()},
#     518     self.edges,
#     519 )
#
# File d:\Lakshya\venv\Lib\site-packages\langchain_core\runnables\graph_ascii.py:299, in draw_ascii(vertices, edges)
#     296 xlist: list[float] = []
#     297 ylist: list[float] = []
# --> 299 sug = _build_sugiyama_layout(vertices, edges)
#     301 for vertex in sug.g.sV:
#     302     # NOTE: moving boxes w/2 to the left
#     303     xlist.extend(
#     304         (
#     305             vertex.view.xy[0] - vertex.view.w / 2.0,
#     306             vertex.view.xy[0] + vertex.view.w / 2.0,
#     307         )
#     308     )
#
# File d:\Lakshya\venv\Lib\site-packages\langchain_core\runnables\graph_ascii.py:206, in _build_sugiyama_layout(vertices, edges)
#     204 if not _HAS_GRANDALF:
#     205     msg = "Install grandalf to draw graphs: `pip install grandalf`."
# --> 206     raise ImportError(msg)
#     208 #
#     209 # Just a reminder about naming conventions:
#     210 # +------------X
#    (...)    215 # Y
#     216 #
#     218 vertices_ = {id_: Vertex(f" {data} ") for id_, data in vertices.items()}
#
# ImportError: Install grandalf to draw graphs: `pip install grandalf`.
