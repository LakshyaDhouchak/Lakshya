# %%
from langchain_ollama import ChatOllama
from dotenv import load_dotenv
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
load_dotenv()
model = ChatOllama(model ='minimax-m3:cloud', temperature= 0.5)
prompt = ChatPromptTemplate([
    ('human','Generate 5 interesting facts about {topic}')
])
parser = StrOutputParser()

# %%
chain = prompt | model | parser
result = chain.invoke({'topic':'black hole'})
print(result)
# Out:
# # 5 Fascinating Facts About Black Holes
#
# ## 1. 🌌 They Can Warp Time Itself
# According to Einstein's theory of general relativity, the massive gravity of a black hole actually **slows down time** near its event horizon. An astronaut hovering near a black hole for what felt like a few hours could return to find years or even centuries have passed on Earth. This phenomenon is called *gravitational time dilation*.
#
# ## 2. 🕳️ There Are Different "Sizes"
# Black holes come in three main categories:
# - **Stellar black holes** (~10-100 solar masses) — formed from collapsed stars
# - **Supermassive black holes** (millions to billions of solar masses) — found at the centers of galaxies, including our own Milky Way (Sagittarius A*)
# - **Intermediate and primordial black holes** — hypothesized smaller or ancient varieties
#
# ## 3. 💫 The Closest Known Black Hole Is "Right Next Door"
# In 2022, scientists discovered **Gaia BH1**, about 1,560 light-years away in the constellation Ophiuchus — making it the closest known black hole to Earth. While that sounds far, it's remarkably close by cosmic standards.
#
# ## 4. 🔊 Black Holes Have "Sound"
# In 2003, NASA detected **sound waves** emanating from the supermassive black hole in the Perseus galaxy cluster. The note? A B-flat, but **57 octaves below middle C** — far too low for human ears to detect. The pressure waves were caused by hot gas rippling around the black hole.
#
# ## 5. 🌟 Information Paradox & Hawking Radiation
# Stephen Hawking theorized that black holes aren't entirely "black" — they emit tiny amounts of radiation (*Hawking radiation*) and can theoretically **evaporate** over incomprehensibly long timescales. He also sparked one of physics' biggest debates: the **information paradox**, questioning whether information that falls into a black hole is truly lost forever. Recent research suggests it may be preserved in the Hawking radiation itself.
#
# ---
#
# Would you like to dive deeper into any of these facts, or explore other cosmic mysteries? 🚀
